# %%
import pyautogui
import pandas as pd
import time

tabela = pd.read_csv("produtos.csv")
print(tabela)

# Define o tempo de espera entre os comandos do pyautogui
pyautogui.PAUSE = 0.5

# Abrir o navegador no macOS usando Spotlight
pyautogui.hotkey("command", "space")  # Abre o Spotlight
pyautogui.write("https://dlp.hashtagtreinamentos.com/python/intensivao/login")            # Digita a url que deseja acessar
pyautogui.press("enter")             

# Espera carregar a página
time.sleep(5)

# Fazer o login  # Clique no campo de e-mail (ajuste coordenadas)
time.sleep(1)
pyautogui.write("rafaelfossali@gmail.com")
time.sleep(1)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write("rafaelfossali@gmail.com")
pyautogui.press("tab")
pyautogui.write("123456")
pyautogui.press("enter")

#Depois estudar o porque que só ocorre o preenchimento correto quando é informado da forma que esta no código acima.
